# %%
import xml.etree.ElementTree as et
from xml.etree.ElementTree import Element
import unicodedata
import os

# %%
# FIXME: names have to be proofread
NAME_TO_MSTRKS = [
  ({"Rast", "Evc", "Rehavi", "Pencgah", "Sazkar", "Sazkar", "Neva", "Neva Buselik", "Tahir", "Tahir-Buselik", "Huseyni", "Huseyni Asiran", "Gulizar", "Yegah", "Beyati Araban", "Muhayyer", "Muhayyer Buselik", "Gerdaniye",  "Gerdaniye Buselik", "Dilkes Haveran", "Evc-Buselik", "Irak", "Pesendide"}, ["B -0.5", "F 1"]), 
  ({"Acem Kurdi", "Acem Asiran", "Kurdi", "Muhayyer-Kurdi"}, ["B -1"]), 
  ({"Muhayyer Sunbule", "Saba", "Saba Buselik", "Saba-Zemzeme", 
  "Bestenigar", "Sevk Efza", "Sevk-i-Tarab", "Sevk u Tarab"}, ["B -0.5", "D -0.25"]), 
  ({"Ussak", "Beyati", "Beyati-Buselik", "Isfahan", "Berte-Isfahan", "Hisar"}, ["B -0.5"]), 
  ({"Nisaburek", "Evc Ara", "Ferahnak"}, ["F 1", "C 1"]),
  ({"Suzidilara", "Mahur", "Mahur-Buselik", "Zavil"}, ["F 0.25"]),
  ({"Nikriz", "Sehnaz"}, ["B -0.25", "C 1"]), 
  ({"Hisar-Buselik", "Suzdil"}, ["F 0.5", "G 1", "D 1"]), 
  ({"Segah", "Mustear"}, ["B -0.5","E -0.5", "F 1"]), 
  ({"Huzzam", "Karcigar", "Beyati Araban-Buselik"}, ["B -0.5", "E -0.25", "F 1"]), 
  ({"Kurdili Hicazkar"}, ["B -1", "E -1", "A -1"]), 
  ({"Hicazkar"}, ["B -0.5", "E -0.25", "A -0.25", "F 1"]), 
  ({"Neveser"}, ["B -0.25", "E -0.25", "F 1", "C 1"]), 
  ({"Hicaz", "Hicaz Asiran", "Hicaz-Buselik"}, ["B -0.25", "F 1", "C 1"]), 
  ({"Arazbar", "Arazbar-Buselik"}, ["B -0.5", "E -0.5"]), 
  ({"Buselik-Asiran"}, ["F 1"]) 
]

ALL_NAMES = set()
for names, _ in NAME_TO_MSTRKS:
  ALL_NAMES |= names

def mstrks(name):
  for names, strks in NAME_TO_MSTRKS:
    if name in names:
      return strks
  assert False, "couldn't find name"

NUM_TO_ACC = {
  "-1": "flat",
  "-0.5": "quarter-flat",
  "-0.25": "slash-flat",
  "0.25": "slash-quarter-sharp",
  "0.5": "quarter-sharp",
  "1": "sharp",
}

def strks_to_xml(strks):
  """

  Helper. Takes strks, which is a string for key signature in the format:
  "note Ahalf-steps"

  and turns them into a tuple of XML Elements.
  """

  key_step = strks[0] #just the first letter. varname \approx strname
  key_alter = strks[2:] #second til end is the number.
  key_accidental = NUM_TO_ACC[strks[2:]] #gives the right name

  step_element = Element("key-step")
  step_element.text = key_step
  alter_element = Element("key-alter")
  alter_element.text = key_alter
  accidental_element = Element("key-accidental")
  accidental_element.text = key_accidental

  return (
    step_element,
    alter_element,
    accidental_element
  )

def insertks(filepath, elements, outpath):
  """insert the key elements into the key node of the file

  :param filepath: file to use
  :param elements: key elements from strks_to_xml
  """
  tree = et.parse(filepath)
  root = tree.getroot()

  key_element = root.findall("./part[@id='P1']/measure[@number='1']/attributes/key")[0]
  key_element.clear()
  for element in elements:
    key_element.append(element)
  tree.write(outpath)

# %%
# https://stackoverflow.com/a/517974
def remove_accents(input_str):
  nfkd_form = unicodedata.normalize('NFKD', input_str)
  return u"".join([c for c in nfkd_form if not unicodedata.combining(c)]).replace("ı", "i")

# %%
folder_path = '../Corrected Transcriptions/MusicXML/'
out_path = '../With Key Signatures/'

# %%
for musicfile in os.listdir(folder_path): #"." refers to current directory.
  #now, we know the string of folder, and can access all the files within!
  if musicfile[0] == "." or not musicfile.endswith('.musicxml'):
    """
    Quick tech note: "." indicates a file is HIDDEN.
    We don't wish to access hidden files, like .DS_Store and .mscbackup.
    Therefore, if a file starts with ., we are guaranteed that it's hidden.
    Of course, we don't have pathological file names that intentionally
    start with ".", so we assume start with "." -> don't consider it.
    """
    print("doesn't end with .musicxml:", musicfile)
    print()
    continue
  #now we are faced with JUST files. Now modify!

  # modify musicfile to update the key signature
  maqam_name = None
  for name in ALL_NAMES:
    normalized_filepath = remove_accents(musicfile)
    if name in normalized_filepath and (
      maqam_name is None or len(name) > len(maqam_name)
    ):
      maqam_name = name

  # maqam must be in file name
  if maqam_name is None:
    print("couldn't find maqam for:", normalized_filepath)
    print()
    continue

  mstrks_cor = mstrks(maqam_name) #find the correct list of key sigs to modify

  key_elements = []
  for strks in mstrks_cor:
    key_elements += strks_to_xml(strks)

  #at this point mstrks must exist.
  insertks(
    folder_path + musicfile,
    key_elements,
    out_path + musicfile,
  ) #gives us correct modification
# Out:
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 282 -284 Rahatu’l‐ervah Pesrevi [Cifte Duyek].musicxml
#
# Pencgah False
# couldn't find maqam for: CT 94 Nisabur Sema’i Hindularin.musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 125-126  Kocek Pesrevi.musicxml
#
# Pencgah False
# Pencgah False
# doesn't end with .musicxml: .DS_Store
#
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 30 Kemani Tatyos Efendi’nin Suzinak Saz Sema’isi.musicxml
#
# Pencgah False
# couldn't find maqam for: CT 260 Maye Saz Sema’isi. ‘Osman Bey merhumun.musicxml
#
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 35 Sultan Selim Han-i Salis Hazretleri'nin Buzurg Saz Sema'isi.musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 333 Sevk Aver Saz Sema’isi.musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 267-268 Revnaknuma Pesrevi. ‘Osman Bey’in [Hafif].musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 44 Tarz-i Nevin Saz Sema'isi. Dellalzade'nin.musicxml
#
# Pencgah False
# couldn't find maqam for: CT 91 Humayun Saz Sema’isi Veli Dede’nin.musicxml
#
# Pencgah False
# couldn't find maqam for: CT 334-336 Nuhuft Pesrevi. Osman Aga [Devr‐i Kebir].musicxml
#
# Pencgah False
# couldn't find maqam for: CT 89-90 Humayun Pesrevi Veli Dede’nin [Cenber].musicxml
#
# Pencgah False
# couldn't find maqam for: CT 45-46 Tarz-i Nevin Pesrevi. Miskali Ismet Aga [Devr-i Kebir].musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 58-59 Yusuf Pasa merhumun Duhag Pesrevi [Devr-i Kebir].musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 110-112 ‘Acem Murassa’ Pesrevi Hekim‐i sehir Farabi [Berefsan].musicxml
#
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 321 ‘Acem ‘Asiran Saz Sema’isi.musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 241 Sevk‐i Tarab Saz Sema’isi. Kanuni Mehmed Bey.musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 122 Gulizr_Saz Sema’asi. Isak’in.musicxml
#
# Pencgah False
# couldn't find maqam for: CT 337-338 Nuhuft Saz Sema’isi. ‘Atik Ahmed Bey.musicxml
#
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 162 ‘Araban Pesrevi. Nabi Isma’il Dede [Duyek].musicxml
#
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 164 Araban Saz Semaisi. Abdi Efendi.musicxml
#
# Pencgah False
# couldn't find maqam for: CT 316-320 ‘Acem ‘Asiran Pesrevi. Tatar’in [Muhammes].musicxml
#
# Pencgah False
# couldn't find maqam for: CT‐241 Sevk‐i Tarab Saz Sema’isi. Kanuni Mehmed Bey.musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 117-118 Zirgule Saz Sema’isi Tatar’in.musicxml
#
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 57 Dugah Saz Sema'isi. Fera'izcizade Ibrahim Vefa Efendi [Aksak Sema'i].musicxml
#
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 269-270 Revnaknuma Saz Sema’isi. Dede Salih Bey merhumun.musicxml
#
# Pencgah False
# couldn't find maqam for: CT 226-227 Kurd. Saz Sema’isi. Yahya Celebi’nin.musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah True
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 252 Muste’ar Saz Sema’isi. Irtical Dede.musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 92-93 Nisabur Pesrevi Emin Aga’nin.musicxml
#
# Pencgah False
# couldn't find maqam for: CT 251 Muste’ar Pesrevi. Kemenceci Usta Nikolaki [Muhammes].musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 303-304 Buselik ‘Asiran Pesrevi. Isak’in [Usul‐i Sekil].musicxml
#
# Pencgah False
# Pencgah False
# Pencgah False
# Pencgah False
# couldn't find maqam for: CT 258-259 Maye Pesrevi. ‘Osman Bey merhumun [Devr‐i Kebir].musicxml
#
# Pencgah False
# couldn't find maqam for: CT 285 Rahatu’l‐ervah Saz Sema’isi. Karabet’in.musicxml
